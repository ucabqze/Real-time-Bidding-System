# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import math

# %%
train = pd.read_csv('train.csv')
#test = pd.read_csv('test.csv')
validation = pd.read_csv('new_validation.csv')

# %%
XG = pd.read_csv('XG_validation.csv')

# %%
validation_o =  pd.read_csv('validation.csv')

# %%
Ada = pd.read_csv('Ada_validation.csv')

# %%
# c = 6
# lambdas = 0.000025

# %%
c =  np.linspace(6,6 , 1)
lambdas = np.linspace(0.000025,  0.0000025, 1)

# %%
avgCTR = 0.0007375623256619447

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Squared Bidding

# %%
def Non_LinearStrategy(pCTR, base_bid,avgCTR,m,n):
    avgCTR = np.repeat(avgCTR*100, pCTR.shape[0])
    base_bid =  np.repeat(base_bid, pCTR.shape[0])
    m= np.repeat(m, pCTR.shape[0])
    n= np.repeat(n, pCTR.shape[0])
    bidprices  =  base_bid  * ((pCTR['pCTR']/ avgCTR)**2) + m* (pCTR['pCTR']/ avgCTR) + n
    return bidprices

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Expoential Bidding

# %%
def Exp(pCTR, base_bid,avgCTR):
    avgCTR = np.repeat(avgCTR*100, pCTR.shape[0])
    base_bid =  np.repeat(base_bid, pCTR.shape[0])
    bidprices  = base_bid  * np.exp(pCTR['pCTR']/ avgCTR)
    return bidprices

# %%
#lambda_range =np.linspaces (math.exp(-10),     )

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> ORTB1

# %%
def Optimal_RealTime_Bidding_1(pCTR, c, lambdas):
    c= np.repeat(c, pCTR.shape[0])
    lambdas = np.repeat(lambdas, pCTR.shape[0])
    bidprices = np.sqrt( (c/lambdas * pCTR['pCTR'] )+c**2) - c
    return bidprices

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> ORTB2

# %%
def Optimal_RealTime_Bidding_2(pCTR, c, lambdas):
    c= np.repeat(c, pCTR.shape[0])
    lambdas = np.repeat(lambdas, pCTR.shape[0])
    a =  ((pCTR['pCTR'] + np.sqrt( (c**2)*(lambdas**2) + lambdas**2))/(c*lambdas))**(1/3)  
    b = ((c*lambdas)/ (pCTR['pCTR'] + np.sqrt((c**2)*(lambdas**2) + lambdas**2)))**(1/3)  
    bidprices =c*(a - b)
    return bidprices

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Strategy Evaluation

# %%
def Evaluate(validation, pre_bidprices):
    
    bidprice = pre_bidprices
    budget = 6250000

    #find who wins the bid
    payprice = validation['payprice'].values
    win_bid = bidprice>payprice

    spend = np.cumsum(payprice*win_bid)
    enough_budget = spend<budget


    click =  np.sum(validation['click'].values*win_bid*enough_budget)
    impression = np.sum(win_bid*enough_budget)
    spend = np.max(spend*enough_budget)
    ctr = click/impression*100
    cpm = spend/impression*1000
    cpc = spend/click


    return [impression,click, ctr, spend, cpm, cpc]

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Tuning Parameter for Square

# %%
basebids = np.linspace(100, 100, 1)

# %%
range_m = np.linspace(120, 130, 15)

# %%
range_n =np.linspace(2, 10, 10)

# %%
k=0
results  = pd.DataFrame(columns = ["basebid","impression","click","ctr","spend","cpm","cpc","m","n"])     

for basebid in basebids:
    for m in range_m:
        for n in range_n:
            pre_bidprices = Non_LinearStrategy(XG, basebid,avgCTR,m,n)
            impression, click, ctr, spend, cpm, cpc = Evaluate(validation, pre_bidprices)
            results.loc[k]  = np.round(basebid,5) , impression, click, ctr, spend, cpm, cpc, m, n
            k = k+1
# Out:
# /Users/sue/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py:180: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))

# %%
results.click.max()
# Out:
# 144.0

# %%
best = results.loc[(results['click'] == 171)]

# %%
best
# Out:
#      basebid  impression  click       ctr      spend           cpm  \
# 26     100.0    126171.0  171.0  0.135530  6249950.0  49535.550959
# 45     100.0    125001.0  171.0  0.136799  6224354.0  49794.433645
# 55     100.0    125317.0  171.0  0.136454  6244546.0  49829.999122
# 74     100.0    124033.0  171.0  0.137867  6210086.0  50068.014158
# 84     100.0    124374.0  171.0  0.137489  6232575.0  50111.558686
# 94     100.0    124641.0  171.0  0.137194  6249966.0  50143.740824
# 103    100.0    123054.0  171.0  0.138963  6197540.0  50364.392868
# 113    100.0    123388.0  171.0  0.138587  6217980.0  50393.717379
# 122    100.0    121737.0  171.0  0.140467  6162007.0  50617.371875
# 123    100.0    123750.0  171.0  0.138182  6241167.0  50433.672727
# 132    100.0    122083.0  171.0  0.140069  6184400.0  50657.339679
# 133    100.0    123851.0  171.0  0.138069  6249979.0  50463.694278
# 142    100.0    122415.0  171.0  0.139689  6205992.0  50696.336233
#
#               cpc           m         n
# 26   36549.415205  121.428571  7.333333
# 45   36399.730994  122.857143  6.444444
# 55   36517.812865  123.571429  6.444444
# 74   36316.292398  125.000000  5.555556
# 84   36447.807018  125.714286  5.555556
# 94   36549.508772  126.428571  5.555556
# 103  36242.923977  127.142857  4.666667
# 113  36362.456140  127.857143  4.666667
# 122  36035.128655  128.571429  3.777778
# 123  36498.052632  128.571429  4.666667
# 132  36166.081871  129.285714  3.777778
# 133  36549.584795  129.285714  4.666667
# 142  36292.350877  130.000000  3.777778

# %%
basebids = np.linspace(400, 420, 10)

# %%
k=0
results  = pd.DataFrame(columns = ["basebid","impression","click","ctr","spend","cpm","cpc"])     

for basebid in basebids:
    pre_bidprices = Non_LinearStrategy(XG, basebid,avgCTR)
    impression, click, ctr, spend, cpm, cpc = Evaluate(validation, pre_bidprices)
    results.loc[k]  = np.round(basebid,5) , impression, click, ctr, spend, cpm, cpc
    k = k+1
# Out:
# /Users/sue/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py:180: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))

# %%
results.click.max()
# Out:
# 168.0

# %%
results
# Out:
#      basebid  impression  click       ctr      spend           cpm  \
# 0  400.00000     99479.0  168.0  0.168880  6138300.0  61704.480343
# 1  402.22222     99751.0  168.0  0.168419  6157165.0  61725.346112
# 2  404.44444    100030.0  168.0  0.167950  6177625.0  61757.722683
# 3  406.66667    100290.0  168.0  0.167514  6194847.0  61769.338917
# 4  408.88889    100546.0  168.0  0.167088  6211353.0  61776.231775
# 5  411.11111    100838.0  168.0  0.166604  6232792.0  61809.952597
# 6  413.33333    101092.0  168.0  0.166185  6249881.0  61823.695248
# 7  415.55556    101061.0  167.0  0.165247  6249958.0  61843.421300
# 8  417.77778    101025.0  167.0  0.165306  6249954.0  61865.419451
# 9  420.00000    100983.0  166.0  0.164384  6249903.0  61890.644960
#
#             cpc
# 0  36537.500000
# 1  36649.791667
# 2  36771.577381
# 3  36874.089286
# 4  36972.339286
# 5  37099.952381
# 6  37201.672619
# 7  37424.898204
# 8  37424.874251
# 9  37650.018072

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Tuning Parameter for Exponential

# %%
k=0
results  = pd.DataFrame(columns = ["basebid","impression","click","ctr","spend","cpm","cpc"])     

for basebid in basebids:
    pre_bidprices = Exp(XG, basebid,avgCTR)
    impression, click, ctr, spend, cpm, cpc = Evaluate(validation, pre_bidprices)
    results.loc[k]  = np.round(basebid,5) , impression, click, ctr, spend, cpm, cpc
    k = k+1

# %%
results.click.max()
# Out:
# 161.0

# %%
results
# Out:
#       basebid  impression  click      ctr      spend          cpm        cpc
# 0    20.00000     76263.0  124.0  0.16260  2079856.0  27272.15032   16773.03
# 1    23.33333     86822.0  129.0  0.14858  2519716.0  29021.63046   19532.68
# 2    26.66667     95980.0  132.0  0.13753  2967437.0  30917.24318   22480.58
# 3    30.00000    105449.0  139.0  0.13182  3451408.0  32730.59014   24830.27
# 4    33.33333    114634.0  145.0  0.12649  3962357.0  34565.28604   27326.60
# 5    36.66667    124218.0  155.0  0.12478  4525763.0  36434.03532   29198.47
# 6    40.00000    134894.0  157.0  0.11639  5171415.0  38336.87933   32938.95
# 7    43.33333    145988.0  161.0  0.11028  5859432.0  40136.39477   36393.99
# 8    46.66667    149173.0  147.0  0.09854  6249999.0  41897.65574   42517.00
# 9    50.00000    143231.0  140.0  0.09774  6249999.0  43635.79812   44642.85
# 10   53.33333    138297.0  128.0  0.09255  6249999.0  45192.58552   48828.12
# 11   56.66667    133803.0  121.0  0.09043  6249999.0  46710.45492   51652.88
# 12   60.00000    129832.0  114.0  0.08781  6249999.0  48139.12595   54824.55
# 13   63.33333    125877.0  105.0  0.08341  6249999.0  49651.63612   59523.80
# 14   66.66667    122050.0   98.0  0.08029  6249999.0  51208.51290   63775.50
# 15   70.00000    118853.0   95.0  0.07993  6249999.0  52585.95913   65789.46
# 16   73.33333    116295.0   90.0  0.07739  6249999.0  53742.62866   69444.43
# 17   76.66667    114158.0   85.0  0.07446  6249999.0  54748.67289   73529.40
# 18   80.00000    112322.0   80.0  0.07122  6249999.0  55643.58719   78124.99
# 19   83.33333    110401.0   78.0  0.07065  6249999.0  56611.79699   80128.19
# 20   86.66667    108925.0   78.0  0.07161  6249999.0  57378.92128   80128.19
# 21   90.00000    107648.0   76.0  0.07060  6249999.0  58059.59238   82236.83
# 22   93.33333    106340.0   76.0  0.07147  6249999.0  58773.73519   82236.83
# 23   96.66667    105038.0   73.0  0.06950  6249999.0  59502.26585   85616.42
# 24  100.00000    103911.0   72.0  0.06929  6249999.0  60147.61671   86805.54
# 25  103.33333    102857.0   69.0  0.06708  6249999.0  60763.96356   90579.70
# 26  106.66667    101751.0   69.0  0.06781  6249999.0  61424.44792   90579.70
# 27  110.00000    100625.0   66.0  0.06559  6249999.0  62111.79130   94696.95
# 28  113.33333     99539.0   65.0  0.06530  6249999.0  62789.44936   96153.83
# 29  116.66667     98450.0   66.0  0.06704  6249999.0  63483.99187   94696.95
# ..        ...         ...    ...      ...        ...          ...        ...
# 70  253.33333     80108.0   51.0  0.06366  6249999.0  78019.66096  122549.00
# 71  256.66667     80049.0   51.0  0.06371  6249999.0  78077.16524  122549.00
# 72  260.00000     80008.0   51.0  0.06374  6249999.0  78117.17578  122549.00
# 73  263.33333     79955.0   51.0  0.06379  6249999.0  78168.95754  122549.00
# 74  266.66667     79906.0   51.0  0.06382  6249999.0  78216.89235  122549.00
# 75  270.00000     79855.0   51.0  0.06387  6249999.0  78266.84616  122549.00
# 76  273.33333     79837.0   51.0  0.06388  6249999.0  78284.49215  122549.00
# 77  276.66667     79821.0   51.0  0.06389  6249999.0  78300.18416  122549.00
# 78  280.00000     79793.0   51.0  0.06392  6249999.0  78327.66032  122549.00
# 79  283.33333     79781.0   51.0  0.06392  6249999.0  78339.44172  122549.00
# 80  286.66667     79770.0   51.0  0.06393  6249999.0  78350.24445  122549.00
# 81  290.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 82  293.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 83  296.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 84  300.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 85  303.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 86  306.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 87  310.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 88  313.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 89  316.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 90  320.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 91  323.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 92  326.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 93  330.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 94  333.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 95  336.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 96  340.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 97  343.33333     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 98  346.66667     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
# 99  350.00000     79759.0   51.0  0.06394  6249999.0  78361.05016  122549.00
#
# [100 rows x 7 columns]

# %%
best = results.loc[(results['click'] == 161)]

# %%
best
# Out:
#     basebid  impression  click      ctr      spend          cpm       cpc
# 7  43.33333    145988.0  161.0  0.11028  5859432.0  40136.39477  36393.99

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Tuning Parameter for ORTB1

# %%
# c =6 , lambda = 0.000025
c =  np.linspace(1, 10, 10)
lambdas = np.linspace(0.000024,  0.000024, 1)

# %%
k=0
results  = pd.DataFrame(columns = ["impression","click","ctr","spend","cpm","cpc","c","lambdas"])     

for pram_c in c:
    for lamb in lambdas:
        pre_bidprices = Optimal_RealTime_Bidding_1(XG, pram_c, lamb)
        impression, click, ctr, spend, cpm, cpc = Evaluate(validation, pre_bidprices)
        results.loc[k]  = impression, click, ctr, spend, cpm, cpc, pram_c, lamb
        k = k+1

# %%
results.click.max()
# Out:
# 163.0

# %%
results
# Out:
#    impression  click      ctr      spend          cpm       cpc     c  \
# 0     61454.0   97.0  0.15784  1366459.0  22235.47694  14087.21   1.0
# 1     91550.0  123.0  0.13435  2670193.0  29166.49918  21708.89   2.0
# 2    111722.0  140.0  0.12531  3766379.0  33712.06208  26902.71   3.0
# 3    126950.0  145.0  0.11422  4718811.0  37170.62623  32543.52   4.0
# 4    139087.0  154.0  0.11072  5541850.0  39844.48583  35986.04   5.0
# 5    148827.0  163.0  0.10952  6233976.0  41887.39946  38245.25   6.0
# 6    142755.0  145.0  0.10157  6249999.0  43781.29663  43103.44   7.0
# 7    137834.0  140.0  0.10157  6249999.0  45344.39253  44642.85   8.0
# 8    134042.0  134.0  0.09997  6249999.0  46627.16910  46641.78   9.0
# 9    130601.0  127.0  0.09724  6249999.0  47855.67492  49212.59  10.0
#
#     lambdas
# 0  0.000024
# 1  0.000024
# 2  0.000024
# 3  0.000024
# 4  0.000024
# 5  0.000024
# 6  0.000024
# 7  0.000024
# 8  0.000024
# 9  0.000024

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> Tuning Parameter for ORTB2

# %%
# c =6, lambda = 0.0000024
c =  np.linspace(6, 6 , 1)
lambdas = np.linspace(0.0000020,  0.0000030, 10)

# %%
k=0
results  = pd.DataFrame(columns = ["impression","click","ctr","spend","cpm","cpc","c","lambdas"])     

for pram_c in c:
    for lamb in lambdas:
        pre_bidprices = Optimal_RealTime_Bidding_2(XG, pram_c, lamb)
        impression, click, ctr, spend, cpm, cpc = Evaluate(validation, pre_bidprices)
        results.loc[k]  = impression, click, ctr, spend, cpm, cpc, pram_c, lamb
        k = k+1

# %%
results.click.max()
# Out:
# 148.0

# %%
best = results.loc[(results['click'] == 148)]

# %%
best
# Out:
#    impression  click      ctr      spend          cpm       cpc    c   lambdas
# 3    156887.0  148.0  0.09434  6129515.0  39069.61699  41415.64  6.0  0.000002
# 4    154403.0  148.0  0.09585  5957744.0  38585.67515  40255.03  6.0  0.000002
# 5    152116.0  148.0  0.09729  5800513.0  38132.16887  39192.66  6.0  0.000003
# 6    149874.0  148.0  0.09875  5647812.0  37683.73434  38160.89  6.0  0.000003

# %% [markdown]
# <font face="微软雅黑" size=6 color=#000000> run on validation

# %%
bidprices = Optimal_RealTime_Bidding_1(XG,6,0.000025)

# %%
Group_17 = pd.DataFrame(data = list(zip(validation_o["bidid"], bidprices)),
                               columns = ["bidid", "bidprice"])

# %%
Group_17.to_csv("Group_17.csv")
